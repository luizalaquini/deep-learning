# %% [markdown]
# # Pacotes

# %%
import numpy as np
import random
import os
import matplotlib.pyplot as plt
import tensorflow
from tensorflow import keras
from keras.datasets import fashion_mnist
from keras.models import Model
from keras.layers import Input, Dense

# Definir a seed para reprodutibilidade
seed = 0
np.random.seed(seed)
tensorflow.random.set_seed(seed)
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)

initializer = tensorflow.keras.initializers.GlorotUniform(seed=seed)

# %% [markdown]
# # Carrega Dataset

# %%
# Carregar o dataset Fashion MNIST
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Definir os nomes das classes
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# Criar um dicionário para armazenar exemplos de cada classe
samples = {}

# Procurar uma amostra de cada classe
for i in range(len(y_train)):
    label = y_train[i]
    if label not in samples:
        samples[label] = x_train[i]  # Salvar a primeira ocorrência da classe
    if len(samples) == 10:  # Se já temos todas as 10 classes, podemos parar
        break

# Mostrar as imagens
plt.figure(figsize=(10, 5))
for i, (label, image) in enumerate(samples.items()):
    plt.subplot(2, 5, i + 1)
    plt.imshow(image, cmap='gray')
    plt.title(class_names[label])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Carregar o dataset Fashion MNIST
(x_train, _), (x_test, _) = fashion_mnist.load_data()

# Normalizar os valores de pixel para o intervalo [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Redimensionar as imagens para um vetor unidimensional (28x28 = 784)
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %% [markdown]
# # Autoenconder

# %%
# Tamanho da codificação (ou seja, número de neurônios na camada oculta)
encoding_dim = 32

# Entrada
input_img = Input(shape=(784,))
# Camada oculta codificadora
encoded = Dense(encoding_dim, activation='relu')(input_img)
# Camada de saída decodificadora
decoded = Dense(784, activation='sigmoid')(encoded)

# Modelo completo de autoencoder
autoencoder = Model(input_img, decoded)

# %% [markdown]
# # Compila Modelo

# %%
# Compilação do autoencoder
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Treinamento do autoencoder
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))

# Reconstrução das imagens de teste usando o autoencoder treinado
decoded_imgs = autoencoder.predict(x_test)
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.4977 - val_loss: 0.3416
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.3312 - val_loss: 0.3178
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.3125 - val_loss: 0.3072
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.3027 - val_loss: 0.3001
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2963 - val_loss: 0.2956
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.2924 - val_loss: 0.2929
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.2899 - val_loss: 0.2912
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2883 - val_loss: 0.2900
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2872 - val_loss: 0.2891
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2864 - val_loss: 0.2884
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2857 - val_loss: 0.2879
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.2853 - val_loss: 0.2875
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2849 - val_loss: 0.2872
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2846 - val_loss: 0.2869
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2843 - val_loss: 0.2867
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2841 - val_loss: 0.2865
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2839 - val_loss: 0.2863
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2837 - val_loss: 0.2862
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.2835 - val_loss: 0.2861
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2834 - val_loss: 0.2859
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.2833 - val_loss: 0.2858
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2832 - val_loss: 0.2857
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.2830 - val_loss: 0.2856
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2830 - val_loss: 0.2855
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.2829 - val_loss: 0.2855
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2828 - val_loss: 0.2854
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.2827 - val_loss: 0.2853
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2826 - val_loss: 0.2852
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2826 - val_loss: 0.2852
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.2825 - val_loss: 0.2851
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.2824 - val_loss: 0.2851
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2824 - val_loss: 0.2850
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.2823 - val_loss: 0.2850
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2823 - val_loss: 0.2849
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2822 - val_loss: 0.2849
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2822 - val_loss: 0.2849
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2821 - val_loss: 0.2848
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.2821 - val_loss: 0.2848
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2821 - val_loss: 0.2848
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2820 - val_loss: 0.2847
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2820 - val_loss: 0.2847
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2820 - val_loss: 0.2847
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.2819 - val_loss: 0.2846
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2819 - val_loss: 0.2846
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2819 - val_loss: 0.2846
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2818 - val_loss: 0.2846
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.2818 - val_loss: 0.2846
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.2818 - val_loss: 0.2845
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2818 - val_loss: 0.2845
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.2817 - val_loss: 0.2845
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# # Visualiza Resultado

# %%
# Visualização das imagens originais e reconstruídas
n = 10  # Número de imagens para visualizar
plt.figure(figsize=(20, 4))
for i in range(n):
    # Imagem original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Imagem reconstruída
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# # 📌 SSIM (Structural Similarity Index) – Teoria e Aplicação
#
# O Structural Similarity Index (SSIM) é uma métrica usada para medir a similaridade perceptual entre duas imagens. Diferente do MSE (Mean Squared Error), que apenas calcula a diferença ponto a ponto entre os pixels, o SSIM leva em conta características estruturais da imagem, como luminosidade, contraste e estrutura.

# %%
from skimage.metrics import structural_similarity as ssim

# Calcular SSIM para uma imagem de teste
ssim_value = ssim(x_test[0].reshape(28, 28), decoded_imgs[0].reshape(28, 28), data_range=1.0)

print(f'SSIM da reconstrução: {ssim_value:.4f}')
# Out:
# SSIM da reconstrução: 0.7890
